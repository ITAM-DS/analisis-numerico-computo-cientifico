# %% [markdown]
# # PCA con métodos numéricos

# %% [markdown]
# Importamos librerías necesarias

# %%
import numpy as np
import pandas as pd
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# %% [markdown]
# Lectura de archivo

# %%
df = pd.read_csv('data/data_clean.csv')
df.head()
# Out:
#    fecha               estado  abuso_de_confianza  abuso_sexual  acoso_sexual  \
# 0   2015       Aguascalientes           -0.321828     -0.775056     -0.626073
# 1   2015      Baja California            0.454653      1.897813     -0.626073
# 2   2015  Baja California Sur           -0.423176     -0.611943     -0.373160
# 3   2015             Campeche           -0.975132     -0.794629     -0.626073
# 4   2015              Chiapas           -0.836364     -0.235697     -0.626073
#
#    allanamiento_de_morada  amenazas  corrupcion_de_menores  \
# 0               -0.348267 -0.423222              -0.051897
# 1                4.921141  0.897264               3.598762
# 2               -0.420759 -0.507674              -0.782028
# 3               -0.551246 -0.908714              -0.810661
# 4               -0.452978 -0.887060              -0.238009
#
#    dano_a_la_propiedad  delitos_cometidos_por_servidores_publicos  ...  \
# 0            -0.563175                                  -0.476536  ...
# 1             1.880732                                   0.041429  ...
# 2            -0.590641                                  -0.300821  ...
# 3            -1.053646                                  -0.456866  ...
# 4            -0.743366                                  -0.201162  ...
#
#    lesiones  narcomenudeo     rapto      robo  secuestro  trata_de_personas  \
# 0 -0.304111     -0.327414 -0.299997 -0.305706  -0.567412          -0.464197
# 1  0.509443     -0.831965 -0.264573  0.558004  -0.446633           0.551482
# 2 -0.582620     -0.335631 -0.299997 -0.373765  -0.668062          -0.548837
# 3 -0.788027     -0.784303 -0.299997 -0.723597  -0.547282          -0.506517
# 4 -0.598915     -0.237022 -0.122877 -0.423899  -0.466762           3.386919
#
#    violacion_equiparada  violacion_simple  \
# 0             -0.190178         -0.979205
# 1              2.532162          1.463693
# 2             -0.490902         -0.791596
# 3             -0.237661         -1.138871
# 4             -0.324712          1.547517
#
#    violencia_de_genero_en_todas_sus_modalidades_distinta_a_la_violencia_familiar  \
# 0                                          -0.235184
# 1                                          -0.244704
# 2                                          -0.244704
# 3                                          -0.244704
# 4                                          -0.244704
#
#    violencia_familiar
# 0           -0.977450
# 1            2.453825
# 2           -0.483830
# 3           -1.166332
# 4           -0.663328
#
# [5 rows x 30 columns]

# %% [markdown]
# Número de filas y columnas disponibles

# %%
df.shape
# Out:
# (224, 30)

# %%
df.fecha.value_counts()
# Out:
# 2015    32
# 2016    32
# 2017    32
# 2018    32
# 2019    32
# 2020    32
# 2021    32
# Name: fecha, dtype: int64

# %% [markdown]
# Al final del reporte se crea un loop para calcular el índice por año. En esta sección, ilustraremos como se hace para 2015.

# %%
mat = df[df.fecha==2015].drop(columns=['fecha','estado'])
mat.head()
# Out:
#    abuso_de_confianza  abuso_sexual  acoso_sexual  allanamiento_de_morada  \
# 0           -0.321828     -0.775056     -0.626073               -0.348267
# 1            0.454653      1.897813     -0.626073                4.921141
# 2           -0.423176     -0.611943     -0.373160               -0.420759
# 3           -0.975132     -0.794629     -0.626073               -0.551246
# 4           -0.836364     -0.235697     -0.626073               -0.452978
#
#    amenazas  corrupcion_de_menores  dano_a_la_propiedad  \
# 0 -0.423222              -0.051897            -0.563175
# 1  0.897264               3.598762             1.880732
# 2 -0.507674              -0.782028            -0.590641
# 3 -0.908714              -0.810661            -1.053646
# 4 -0.887060              -0.238009            -0.743366
#
#    delitos_cometidos_por_servidores_publicos   despojo  electorales  ...  \
# 0                                  -0.476536 -0.650099    -0.447840  ...
# 1                                   0.041429  0.681356    -0.427542  ...
# 2                                  -0.300821 -0.541435    -0.468139  ...
# 3                                  -0.456866 -0.870044    -0.386944  ...
# 4                                  -0.201162 -0.422298     0.465602  ...
#
#    lesiones  narcomenudeo     rapto      robo  secuestro  trata_de_personas  \
# 0 -0.304111     -0.327414 -0.299997 -0.305706  -0.567412          -0.464197
# 1  0.509443     -0.831965 -0.264573  0.558004  -0.446633           0.551482
# 2 -0.582620     -0.335631 -0.299997 -0.373765  -0.668062          -0.548837
# 3 -0.788027     -0.784303 -0.299997 -0.723597  -0.547282          -0.506517
# 4 -0.598915     -0.237022 -0.122877 -0.423899  -0.466762           3.386919
#
#    violacion_equiparada  violacion_simple  \
# 0             -0.190178         -0.979205
# 1              2.532162          1.463693
# 2             -0.490902         -0.791596
# 3             -0.237661         -1.138871
# 4             -0.324712          1.547517
#
#    violencia_de_genero_en_todas_sus_modalidades_distinta_a_la_violencia_familiar  \
# 0                                          -0.235184
# 1                                          -0.244704
# 2                                          -0.244704
# 3                                          -0.244704
# 4                                          -0.244704
#
#    violencia_familiar
# 0           -0.977450
# 1            2.453825
# 2           -0.483830
# 3           -1.166332
# 4           -0.663328
#
# [5 rows x 28 columns]

# %%
mat.shape
# Out:
# (32, 28)

# %% [markdown]
# ## Funciones definidas

# %%
def givens_rotation(A):
    (r, c) = np.shape(A)
    Q = np.identity(r)
    R = np.copy(A)
    (rows, cols) = np.tril_indices(r, -1, c)
    for (row, col) in zip(rows, cols):
        if R[row, col] != 0:  # Q = 1, s = 0, r, q sin cambios
            r_ = np.hypot(R[col, col], R[row, col])  # d
            c = R[col, col]/r_
            s = -R[row, col]/r_
            G = np.identity(r)
            G[[col, row], [col, row]] = c
            G[row, col] = s
            G[col, row] = -s
            R = np.dot(G, R)  # R=G(n-1,n)*...*G(2n)*...*G(23,1n)*...*G(12)*A
            Q = np.dot(Q, G.T)  # Q=G(n-1,n).T*...*G(2n).T*...*G(23,1n).T*...*G(12).T
    return (Q, R)

# %%
#Algoritmo QR para matrices simetricas (version simple)
def algoritmoQR(matrix):
    #T0
    T_k_minus_1 = matrix
    q,r = givens_rotation(matrix)
    m,n = q.shape
    Q = np.eye(m,n)
    T_k = r@q 
    #Q es la matriz que aproximará a los eigenvectores
    Q = Q@q
    n = 100 # Número de iteraciones
    while n > 0:
        T_k_minus_1 = T_k
        q,r = givens_rotation(T_k_minus_1)
        Q = Q@q
        #T_k es la matriz que aproxima a nuestros eigenvalores
        T_k = r@q
        n = n - 1
    
    return np.diag(T_k), Q

# %%
mat2 = mat.to_numpy()
eigenvalores_u, eigenvectores_u = algoritmoQR(mat2@mat2.T/31) #U

# %% [markdown]
# Empezaremos por hacer una Descomposición en Valores Singulares, y básada en esta, calcularemos el PCA.
#
# Calculamos $U$

# %%
U = pd.DataFrame(eigenvectores_u).iloc[:,0:28]
U.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.114305  0.003642 -0.034741  0.086151  0.036827 -0.083723  0.078544
# 1 -0.210156  0.238246  0.662431  0.231877  0.309507 -0.187994  0.015205
# 2  0.129822 -0.019196 -0.043230  0.027409  0.013588 -0.077741  0.070339
# 3  0.178474 -0.067318 -0.048469  0.085546  0.009729 -0.063551  0.112460
# 4  0.032594 -0.084937  0.037435 -0.049515  0.022346  0.585057  0.369696
#
#          7         8         9   ...        18        19        20        21  \
# 0  0.037378 -0.140191 -0.028213  ...  0.236828  0.199123 -0.604711 -0.152246
# 1  0.083687  0.402487  0.105235  ... -0.031649 -0.116655  0.007744  0.002353
# 2  0.089263 -0.074182 -0.017406  ... -0.034350  0.118785  0.357262  0.060388
# 3  0.001253 -0.000385  0.001549  ... -0.095620  0.001970  0.196710 -0.192747
# 4 -0.144061  0.421201 -0.004438  ...  0.109997  0.081943 -0.037840 -0.010999
#
#          22        23        24        25        26        27
# 0  0.242284  0.159833  0.063958 -0.230778  0.049087 -0.104189
# 1 -0.015761  0.057734 -0.035018 -0.000828  0.002478 -0.000043
# 2  0.237548  0.342337 -0.389599 -0.276608 -0.255176  0.354271
# 3  0.035069 -0.322207 -0.103401 -0.518433  0.333251 -0.036581
# 4  0.019838  0.133583 -0.076755 -0.019860  0.047322  0.012173
#
# [5 rows x 28 columns]

# %% [markdown]
# El índice será construido como la primer dimensión de la matriz
#
# $$U' = UD\Sigma^{-1} $$

# %% [markdown]
# Donde $U$ y $D$ se obtienen de la SVD y
#
# $$\Sigma = \sqrt{\text{eigen}(\frac{1}{n-1}X^{T}X)}$$
#
# Donde $X$ es la matriz de datos originales y $n$ es el número de renglones de dichos datos

# %% [markdown]
# Calculemos, entonces, $\Sigma$

# %%
sigma = np.sqrt(eigenvalores_u)[:-4]
sigma_inv = 1/sigma
sigma_inv
# Out:
# /tmp/ipykernel_16114/672889028.py:1: RuntimeWarning: invalid value encountered in sqrt
#   sigma = np.sqrt(eigenvalores_u)[:-4]
# array([0.267503, 0.521276, 0.638813, 0.786301, 0.884198, 0.943935,
#        1.061116, 1.205543, 1.392077, 1.488319, 1.843190, 2.018406,
#        2.142159, 2.593699, 2.826644, 3.596297, 3.747462, 4.680115,
#        5.398691, 6.303665, 7.906128, 9.023527, 9.792493, 13.908434,
#        24.452650, 33.115381, 51.994803, 71.749987])

# %% [markdown]
# Calculamos $D$

# %%
#eigenvalores_u, eigenvectores_u = algoritmoQR(mat2@mat2.T) #U
D = np.sqrt(eigenvalores_u)[:-4]
D
# Out:
# /tmp/ipykernel_16114/1318903269.py:2: RuntimeWarning: invalid value encountered in sqrt
#   D = np.sqrt(eigenvalores_u)[:-4]
# array([3.738270, 1.918369, 1.565402, 1.271777, 1.130968, 1.059395,
#        0.942404, 0.829501, 0.718351, 0.671899, 0.542538, 0.495440,
#        0.466819, 0.385550, 0.353776, 0.278064, 0.266847, 0.213670,
#        0.185230, 0.158638, 0.126484, 0.110821, 0.102119, 0.071899,
#        0.040895, 0.030197, 0.019233, 0.013937])

# %% [markdown]
# Verificamos dimensiones

# %%
U.shape
# Out:
# (32, 28)

# %%
np.diag(D).shape
# Out:
# (28, 28)

# %%
np.diag(sigma_inv).shape
# Out:
# (28, 28)

# %% [markdown]
# Calculamos $U'$

# %%
U_prime = U@np.diag(D)@np.diag(sigma_inv)

# %%
pd.DataFrame(U_prime)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0
# 5  -0.296340  0.205130  0.594807  0.063377 -0.511366  0.064856
# 6  -0.259044 -0.030213  0.113458 -0.133730  0.190219 -0.121268
# 7   0.165612  0.355403 -0.019272  0.252095  0.341738 -0.122757
# 8   1.190976  0.339754 -1.472344  2.154436 -0.137584 -3.500713
# 9  -1.430502  2.574088  0.765783  0.117960  1.891683 -0.680427
# 10  0.221420 -0.252063 -0.654902  0.252893  0.533309  0.053516
# 11  0.787768 -1.269560 -0.897183 -0.065671  0.888090  0.153957
# 12 -0.979245  1.511212  0.753150 -0.738218  0.448016 -0.341715
# 13  0.188680  0.174509 -0.161267  0.038980 -0.333287  0.053874
# 14  0.062166 -0.055701  0.124774  0.190074  0.096059  0.069213
# 15 -1.451204  1.018230  0.175248 -0.794219 -0.959996 -0.684161
# 16  2.385366 -0.821990 -0.536683  1.075133  0.876837  0.510336
# 17 -2.765064 -0.803163 -2.492719  2.080303  0.501561  1.492951
# 18  0.036196  0.070114 -0.673111 -0.124167  0.770859 -0.151377
# 19 -0.719018 -1.029075  2.161665  1.265124  0.603705 -0.190508
# 20 -0.332220 -0.632118  0.177260  0.002819 -0.276854 -0.063752
# 21 -0.319509 -0.862329 -0.781991  0.399143 -1.095718  1.000136
# 22  0.943634 -1.099307  0.600305 -0.113913 -0.558184 -1.286267
# 23 -0.018502 -1.606099  1.499650 -0.353383 -1.273523  0.941395
# 24  0.184195  0.431386  1.384324  0.793444 -2.364956  0.812373
# 25 -0.451925 -0.869906  1.030972 -0.963667  1.084590  0.144039
# 26 -1.402667 -0.519088 -0.426439 -0.832386 -0.071615 -0.267233
# 27  0.245132  0.671397  0.383021  0.217845 -0.118374  0.061122
# 28  1.623821  1.116013  1.397595  1.532186  1.378048  2.187703
# 29 -0.097486  0.220051 -0.439832 -0.351720 -0.263104 -0.182755
# 30 -0.232503 -0.650392  0.522428  0.396931 -0.397877  0.087024
# 31 -0.169288 -0.253475 -0.117569 -0.534963 -2.227554 -1.295819
#
# [32 rows x 28 columns]

# %% [markdown]
# Así, el índice es la primer columna de $U'$

# %%
indice = pd.DataFrame({'estado' : df[df.fecha==2015]['estado'], 'indice' : -U_prime.iloc[:,0]})

indice.sort_values(['indice'], ascending = False)
# Out:
#                              estado    indice
# 14                           México  2.712295
# 6                  Ciudad de México  2.391905
# 1                   Baja California  1.129211
# 13                          Jalisco  0.975302
# 18                       Nuevo León  0.506639
# 20                           Puebla  0.406222
# 10                       Guanajuato  0.362501
# 5                         Chihuahua  0.214936
# 16                          Morelos -0.208315
# 27                       Tamaulipas -0.211397
# 29  Veracruz de Ignacio de la Llave -0.231328
# 4                           Chiapas -0.417009
# 26                          Tabasco -0.468001
# 7              Coahuila de Zaragoza -0.504481
# 22                     Quintana Roo -0.517792
# 30                          Yucatán -0.543622
# 11                         Guerrero -0.589351
# 24                          Sinaloa -0.642436
# 15              Michoacán de Ocampo -0.663243
# 12                          Hidalgo -0.724624
# 23                  San Luis Potosí -0.749984
# 21                        Querétaro -0.764842
# 25                           Sonora -0.768843
# 9                           Durango -0.811367
# 0                    Aguascalientes -0.879619
# 31                        Zacatecas -0.974630
# 2               Baja California Sur -0.980413
# 17                          Nayarit -1.134417
# 19                           Oaxaca -1.142928
# 28                         Tlaxcala -1.151177
# 8                            Colima -1.216049
# 3                          Campeche -1.240976

# %%
indice = pd.DataFrame({'estado' : df[df.fecha==2015]['estado']})
for i in df.fecha.unique():
    print('Seleccionamos año: '+str(i))
    mat = df[df.fecha==i].drop(columns=['fecha','estado'])
    print('Aplicamos función Algortimo QR a datos estandarizados')
    mat2 = mat.to_numpy()
    print('Obtenemos U')
    eigenvalores_u, eigenvectores_u = algoritmoQR(mat2@mat2.T/31) #U
    print('Calculamos Sigma inversa')
    sigma = np.sqrt(eigenvalores_u)[:-4]
    sigma_inv = 1/sigma
    print('Calculamos D')
    eigenvalores2, eigenvectores2 = algoritmoQR(mat2@mat2.T) 
    D = np.sqrt(eigenvalores2)[:-4]
    print("Obtenemos U'")
    U_prime = U@np.diag(D)@np.diag(sigma_inv)
    print("Seleccionamos la primera columna de U' como índice")
    print('Almacenamos')
    indice[i] = -U_prime.iloc[:,0]
    print('***')
# Out:
# Seleccionamos año: 2015
# Aplicamos función Algortimo QR a datos estandarizados
# Obtenemos U
# Calculamos Sigma inversa
# Calculamos D
# /Users/pau/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# /Users/pau/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
# Obtenemos U'
# Seleccionamos la primera columna de U' como índice
# Almacenamos
# ***
# Seleccionamos año: 2016
# Aplicamos función Algortimo QR a datos estandarizados
# Obtenemos U
# Calculamos Sigma inversa
# Calculamos D
# Obtenemos U'
# Seleccionamos la primera columna de U' como índice
# Almacenamos
# ***
# Seleccionamos año: 2017
# Aplicamos función Algortimo QR a datos estandarizados
# Obtenemos U
# Calculamos Sigma inversa
# Calculamos D
# Obtenemos U'
# Seleccionamos la primera columna de U' como índice
# Almacenamos
# ***
# Seleccionamos año: 2018
# Aplicamos función Algortimo QR a datos estandarizados
# Obtenemos U
# Calculamos Sigma inversa
# Calculamos D
# Obtenemos U'
# Seleccionamos la primera columna de U' como índice
# Almacenamos
# ***
# Seleccionamos año: 2019
# Aplicamos función Algortimo QR a datos estandarizados
# Obtenemos U
# Calculamos Sigma inversa
# Calculamos D
# Obtenemos U'
# Seleccionamos la primera columna de U' como índice
# Almacenamos
# ***
# Seleccionamos año: 2020
# Aplicamos función Algortimo QR a datos estandarizados
# Obtenemos U
# Calculamos Sigma inversa
# Calculamos D
# Obtenemos U'
# Seleccionamos la primera columna de U' como índice
# Almacenamos
# ***
# Seleccionamos año: 2021
# Aplicamos función Algortimo QR a datos estandarizados
# Obtenemos U
# Calculamos Sigma inversa
# Calculamos D
# Obtenemos U'
# Seleccionamos la primera columna de U' como índice
# Almacenamos
# ***

# %%
indice
# Out:
#                              estado      2015      2016      2017      2018  \
# 0                    Aguascalientes -0.879619 -0.879619 -0.879619 -0.879619
# 1                   Baja California  1.129211  1.129211  1.129211  1.129211
# 2               Baja California Sur -0.980413 -0.980413 -0.980413 -0.980413
# 3                          Campeche -1.240976 -1.240976 -1.240976 -1.240976
# 4                           Chiapas -0.417009 -0.417009 -0.417009 -0.417009
# 5                         Chihuahua  0.214936  0.214936  0.214936  0.214936
# 6                  Ciudad de México  2.391905  2.391905  2.391905  2.391905
# 7              Coahuila de Zaragoza -0.504481 -0.504481 -0.504481 -0.504481
# 8                            Colima -1.216049 -1.216049 -1.216049 -1.216049
# 9                           Durango -0.811367 -0.811367 -0.811367 -0.811367
# 10                       Guanajuato  0.362501  0.362501  0.362501  0.362501
# 11                         Guerrero -0.589351 -0.589351 -0.589351 -0.589351
# 12                          Hidalgo -0.724624 -0.724624 -0.724624 -0.724624
# 13                          Jalisco  0.975302  0.975302  0.975302  0.975302
# 14                           México  2.712295  2.712295  2.712295  2.712295
# 15              Michoacán de Ocampo -0.663243 -0.663243 -0.663243 -0.663243
# 16                          Morelos -0.208315 -0.208315 -0.208315 -0.208315
# 17                          Nayarit -1.134417 -1.134417 -1.134417 -1.134417
# 18                       Nuevo León  0.506639  0.506639  0.506639  0.506639
# 19                           Oaxaca -1.142928 -1.142928 -1.142928 -1.142928
# 20                           Puebla  0.406222  0.406222  0.406222  0.406222
# 21                        Querétaro -0.764842 -0.764842 -0.764842 -0.764842
# 22                     Quintana Roo -0.517792 -0.517792 -0.517792 -0.517792
# 23                  San Luis Potosí -0.749984 -0.749984 -0.749984 -0.749984
# 24                          Sinaloa -0.642436 -0.642436 -0.642436 -0.642436
# 25                           Sonora -0.768843 -0.768843 -0.768843 -0.768843
# 26                          Tabasco -0.468001 -0.468001 -0.468001 -0.468001
# 27                       Tamaulipas -0.211397 -0.211397 -0.211397 -0.211397
# 28                         Tlaxcala -1.151177 -1.151177 -1.151177 -1.151177
# 29  Veracruz de Ignacio de la Llave -0.231328 -0.231328 -0.231328 -0.231328
# 30                          Yucatán -0.543622 -0.543622 -0.543622 -0.543622
# 31                        Zacatecas -0.974630 -0.974630 -0.974630 -0.974630
#
#         2019      2020      2021
# 0  -0.879619 -0.879619 -0.879619
# 1   1.129211  1.129211  1.129211
# 2  -0.980413 -0.980413 -0.980413
# 3  -1.240976 -1.240976 -1.240976
# 4  -0.417009 -0.417009 -0.417009
# 5   0.214936  0.214936  0.214936
# 6   2.391905  2.391905  2.391905
# 7  -0.504481 -0.504481 -0.504481
# 8  -1.216049 -1.216049 -1.216049
# 9  -0.811367 -0.811367 -0.811367
# 10  0.362501  0.362501  0.362501
# 11 -0.589351 -0.589351 -0.589351
# 12 -0.724624 -0.724624 -0.724624
# 13  0.975302  0.975302  0.975302
# 14  2.712295  2.712295  2.712295
# 15 -0.663243 -0.663243 -0.663243
# 16 -0.208315 -0.208315 -0.208315
# 17 -1.134417 -1.134417 -1.134417
# 18  0.506639  0.506639  0.506639
# 19 -1.142928 -1.142928 -1.142928
# 20  0.406222  0.406222  0.406222
# 21 -0.764842 -0.764842 -0.764842
# 22 -0.517792 -0.517792 -0.517792
# 23 -0.749984 -0.749984 -0.749984
# 24 -0.642436 -0.642436 -0.642436
# 25 -0.768843 -0.768843 -0.768843
# 26 -0.468001 -0.468001 -0.468001
# 27 -0.211397 -0.211397 -0.211397
# 28 -1.151177 -1.151177 -1.151177
# 29 -0.231328 -0.231328 -0.231328
# 30 -0.543622 -0.543622 -0.543622
# 31 -0.974630 -0.974630 -0.974630
