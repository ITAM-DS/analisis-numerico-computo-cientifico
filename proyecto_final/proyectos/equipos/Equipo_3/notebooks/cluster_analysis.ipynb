# %% [markdown]
# # Additional analysis for project

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %% [markdown]
# #### Python libraries

# %%
import pandas as pd

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

import seaborn as sns

import sys

# %% [markdown]
# #### Ancillary modules

# %%
sys.path.append("../")

# %%
# %load_ext autoreload
# %autoreload 2

from utils.functions import (
    json_dump_dict,
    adding_cluster_feature,
    cluster_dictionary,
    finding_clusters_match,
    clustering_dataframes,
    display_confusion_matrix,
    render_mpl_table
)

from utils.parameters import (
    gm_rename,
    yr,
    original_features
)

# %% [markdown]
# #### Data

# %%
df_ime_cmp = pd.read_csv("../data/base.csv")
df_ime_cmp["GM"] = df_ime_cmp["GM"].map(gm_rename)
df_ime = df_ime_cmp.loc[df_ime_cmp["A.O"] == yr, :].copy()
df_ime
# Out:
#      Unnamed: 0  CVE_ENT                          NOM_ENT   POB_TOT  ANALF  \
# 160         161        1                   Aguascalientes   1312544   2.60
# 161         162        2                  Baja California   3315766   1.96
# 162         163        3              Baja California Sur    712029   2.51
# 163         164        4                         Campeche    899931   6.68
# 164         165        5             Coahuila de Zaragoza   2954915   1.99
# 165         166        6                           Colima    711235   3.90
# 166         167        7                          Chiapas   5217908  14.98
# 167         168        8                        Chihuahua   3556574   2.67
# 168         169        9                 Distrito Federal   8918653   1.49
# 169         170       10                          Durango   1754754   3.17
# 170         171       11                       Guanajuato   5853677   6.39
# 171         172       12                         Guerrero   3533251  13.73
# 172         173       13                          Hidalgo   2858359   8.26
# 173         174       14                          Jalisco   7844830   3.55
# 174         175       15                           México  16187608   3.37
# 175         176       16              Michoacán de Ocampo   4584471   8.35
# 176         177       17                          Morelos   1903811   4.99
# 177         178       18                          Nayarit   1181050   5.07
# 178         179       19                       Nuevo León   5119504   1.64
# 179         180       20                           Oaxaca   3967889  13.65
# 180         181       21                           Puebla   6168883   8.39
# 181         182       22                        Querétaro   2038372   4.57
# 182         183       23                     Quintana Roo   1501562   3.90
# 183         184       24                  San Luis Potosí   2717820   6.33
# 184         185       25                          Sinaloa   2966321   4.18
# 185         186       26                           Sonora   2850330   2.19
# 186         187       27                          Tabasco   2395272   5.40
# 187         188       28                       Tamaulipas   3441698   3.03
# 188         189       29                         Tlaxcala   1272847   3.98
# 189         190       30  Veracruz de Ignacio de la Llave   8112505   9.51
# 190         191       31                          Yucatán   2097175   7.47
# 191         192       32                        Zacatecas   1579209   4.42
#
#      SPRIM  OVSDE  OVSEE  OVSAE   VHAC   OVPT  PL.5000  PO2SM    IM  \
# 160  11.89   0.67   0.30   0.81  21.86   0.75    25.16  34.60 -0.89
# 161  10.46   0.26   0.47   2.82  23.03   1.15    10.35  22.85 -1.10
# 162  11.59   0.38   1.14   7.15  26.23   4.08    15.62  22.37 -0.60
# 163  18.56   4.08   1.59   6.49  37.93   2.95    30.88  40.69  0.46
# 164   9.56   0.62   0.29   1.67  23.62   0.66    12.15  27.94 -1.10
# 165  15.24   0.38   0.38   0.96  25.65   2.45    14.47  31.18 -0.73
# 166  31.71   2.90   2.49  13.45  44.46  11.78    57.86  62.46  2.41
# 167  12.65   1.40   1.81   2.39  22.16   1.76    17.05  34.77 -0.60
# 168   6.62   0.04   0.04   1.10  19.19   0.47     0.67  28.26 -1.45
# 169  14.50   3.68   2.63   3.26  24.58   4.33    36.19  39.16  0.05
# 170  19.12   3.31   0.68   4.13  25.36   2.00    34.67  37.41 -0.07
# 171  27.25  13.03   2.40  15.64  42.11  14.86    49.68  53.29  2.56
# 172  18.13   3.09   1.12   5.83  28.17   3.19    58.71  46.22  0.50
# 173  14.90   0.86   0.34   1.84  22.12   1.59    17.50  29.40 -0.82
# 174  11.77   1.68   0.38   4.03  28.53   1.92    19.11  35.28 -0.57
# 175  25.35   2.32   0.81   4.26  28.05   5.90    40.58  44.88  0.50
# 176  15.09   1.03   0.44   5.81  27.04   3.88    24.65  42.08 -0.20
# 177  17.56   4.66   2.54   4.36  27.63   3.92    39.14  37.96  0.31
# 178   8.38   0.16   0.12   1.36  23.09   0.80     6.70  16.15 -1.39
# 179  29.22   2.44   2.87  13.05  38.33  13.44    61.51  49.46  2.12
# 180  21.32   1.58   0.88   6.94  35.27   5.69    38.50  52.16  0.69
# 181  13.01   2.93   0.67   3.23  24.21   1.52    39.07  25.92 -0.49
# 182  13.32   2.19   1.11   2.70  36.31   2.41    14.36  28.32 -0.37
# 183  18.87   2.34   2.29  10.68  25.21   5.56    40.08  43.64  0.58
# 184  16.82   2.57   0.52   2.99  30.37   2.85    32.85  32.70 -0.24
# 185  11.15   1.05   1.05   2.52  26.63   2.61    17.39  29.93 -0.70
# 186  17.25   1.81   0.43  10.10  32.50   3.69    53.65  36.96  0.30
# 187  13.35   0.37   0.73   2.51  28.69   1.52    13.92  37.39 -0.62
# 188  12.60   1.36   0.47   1.14  32.00   2.00    36.40  51.47 -0.20
# 189  25.04   1.53   1.62  13.39  32.03   6.84    46.20  49.68  1.14
# 190  21.17  10.10   1.08   1.64  36.42   1.67    26.27  47.60  0.51
# 191  19.31   4.17   0.62   3.13  24.99   1.25    48.19  45.40  0.01
#
#              GM  LUGAR   A.O
# 160      1_bajo     28  2015
# 161  0_muy_bajo     30  2015
# 162      1_bajo     22  2015
# 163      3_alto     10  2015
# 164  0_muy_bajo     29  2015
# 165      1_bajo     26  2015
# 166  4_muy_alto      2  2015
# 167      1_bajo     23  2015
# 168  0_muy_bajo     32  2015
# 169     2_medio     13  2015
# 170     2_medio     15  2015
# 171  4_muy_alto      1  2015
# 172      3_alto      9  2015
# 173      1_bajo     27  2015
# 174      1_bajo     21  2015
# 175      3_alto      8  2015
# 176     2_medio     17  2015
# 177     2_medio     11  2015
# 178  0_muy_bajo     31  2015
# 179  4_muy_alto      3  2015
# 180      3_alto      5  2015
# 181      1_bajo     20  2015
# 182     2_medio     19  2015
# 183      3_alto      6  2015
# 184     2_medio     18  2015
# 185      1_bajo     25  2015
# 186     2_medio     12  2015
# 187      1_bajo     24  2015
# 188     2_medio     16  2015
# 189      3_alto      4  2015
# 190      3_alto      7  2015
# 191     2_medio     14  2015

# %%
df_pca = pd.read_csv("../data/PCA_" + str(yr) + ".csv")
df_pca["GM"] = df_pca["GM"].map(gm_rename)
df_pca["A.O"] = yr
df_pca["NOM_ENT"] = df_ime["NOM_ENT"].values
df_pca
# Out:
#       PC1    PC2    PC3    PC4    PC5    PC6    PC7    PC8    PC9          GM  \
# 0   0.270 -0.114 -0.261 -1.613  0.324 -0.846 -1.391  0.568  0.290      1_bajo
# 1  -0.335 -0.960 -1.055 -1.758  0.792 -0.626 -1.423 -0.091  0.652  0_muy_bajo
# 2  -0.653 -1.395 -1.212 -0.916  0.827 -0.286 -0.266 -0.324  0.042      1_bajo
# 3  -0.778  0.424  0.528  1.182 -0.020  0.123  0.655 -0.498  0.481      3_alto
# 4  -0.259 -0.628 -0.688 -1.726  0.811 -0.667 -1.554  0.304  0.802  0_muy_bajo
# 5  -0.287  0.037 -0.729 -1.351  0.138  0.004 -1.317  0.092  0.426      1_bajo
# 6  -0.084  2.235  0.304  3.807 -1.097  2.119  3.455 -0.362 -1.884  4_muy_alto
# 7  -0.281 -0.965 -0.243 -0.200  0.356 -0.785 -1.642 -0.002 -0.457      1_bajo
# 8   0.010 -0.938 -0.980 -2.138  1.361 -0.530 -2.333  0.602  0.821  0_muy_bajo
# 9  -0.222 -1.289  0.566  0.912 -0.562 -0.802 -0.635  0.151 -0.977     2_medio
# 10  0.820  0.304  0.212 -0.346 -0.286 -0.140 -0.246 -0.338  0.219     2_medio
# 11  0.856 -0.570  2.043  4.305 -1.295  3.329  3.821 -0.693 -0.045  4_muy_alto
# 12  1.083  0.800  0.480  0.634 -0.641 -0.645  0.959  0.372 -0.363      3_alto
# 13  0.227 -0.268 -0.641 -1.558  0.238 -0.292 -1.350 -0.092  0.356      1_bajo
# 14 -0.300 -0.121 -0.174 -0.955  0.798 -0.211 -0.605  0.348  0.710      1_bajo
# 15  0.719  1.109  0.128  0.146 -0.991  0.857  0.393 -0.175 -0.676      3_alto
# 16  0.201  0.317 -0.223 -0.616  0.704  0.279 -0.160  0.444 -0.110     2_medio
# 17 -0.091 -0.889  0.643  1.257 -0.789 -0.578 -0.127 -0.368 -0.600     2_medio
# 18 -0.467 -1.199 -1.408 -2.278  0.715 -0.720 -1.653 -0.035  1.266  0_muy_bajo
# 19  0.118  0.828 -0.440  3.317 -1.587  1.658  3.317 -0.433 -2.225  4_muy_alto
# 20 -0.050  1.548  0.226  0.778 -0.036  0.825  1.040  0.351 -0.476      3_alto
# 21  0.574 -0.667 -0.282 -0.946 -0.357 -1.031 -0.237 -0.053  0.713      1_bajo
# 22 -1.550 -0.265 -0.382 -0.168  0.187 -0.113 -0.465 -0.212  1.170     2_medio
# 23  0.530 -0.525  0.041  1.239  0.243 -0.097  0.776 -0.386 -1.620      3_alto
# 24 -0.233  0.119  0.075 -0.811 -0.328 -0.185 -0.025 -0.035  0.607     2_medio
# 25 -0.704 -0.816 -0.503 -0.876  0.411 -0.528 -1.048  0.246  0.288      1_bajo
# 26  0.308  0.495  0.049 -0.456  0.223 -0.442  1.942 -0.027 -0.009     2_medio
# 27 -0.728  0.161 -0.311 -0.827  0.733 -0.256 -1.148  0.258  0.278      1_bajo
# 28 -0.366  1.134  0.711 -0.384  0.229 -0.495 -0.389  1.401  0.245     2_medio
# 29  0.578  1.005 -0.069  1.446  0.191  0.818  2.049 -0.605 -1.574      3_alto
# 30  0.113  0.521  2.330  1.395 -0.793  0.866 -0.312 -0.530  1.735      3_alto
# 31  0.984  0.570  1.266 -0.494 -0.499 -0.602 -0.083  0.123 -0.087     2_medio
#
#       IM   A.O                          NOM_ENT
# 0  -0.89  2015                   Aguascalientes
# 1  -1.10  2015                  Baja California
# 2  -0.60  2015              Baja California Sur
# 3   0.46  2015                         Campeche
# 4  -1.10  2015             Coahuila de Zaragoza
# 5  -0.73  2015                           Colima
# 6   2.41  2015                          Chiapas
# 7  -0.60  2015                        Chihuahua
# 8  -1.45  2015                 Distrito Federal
# 9   0.05  2015                          Durango
# 10 -0.07  2015                       Guanajuato
# 11  2.56  2015                         Guerrero
# 12  0.50  2015                          Hidalgo
# 13 -0.82  2015                          Jalisco
# 14 -0.57  2015                           México
# 15  0.50  2015              Michoacán de Ocampo
# 16 -0.20  2015                          Morelos
# 17  0.31  2015                          Nayarit
# 18 -1.39  2015                       Nuevo León
# 19  2.12  2015                           Oaxaca
# 20  0.69  2015                           Puebla
# 21 -0.49  2015                        Querétaro
# 22 -0.37  2015                     Quintana Roo
# 23  0.58  2015                  San Luis Potosí
# 24 -0.24  2015                          Sinaloa
# 25 -0.70  2015                           Sonora
# 26  0.30  2015                          Tabasco
# 27 -0.62  2015                       Tamaulipas
# 28 -0.20  2015                         Tlaxcala
# 29  1.14  2015  Veracruz de Ignacio de la Llave
# 30  0.51  2015                          Yucatán
# 31  0.01  2015                        Zacatecas

# %% [markdown]
# ---

# %% [markdown]
# ## Clustering exercise

# %% [markdown]
# ### Clustering algorithm

# %%
df_ime = adding_cluster_feature(df_ime, "orig")
# Out:
# Features fed for clustering analysis (9):
# 1. ANALF
# 2. SPRIM
# 3. OVSDE
# 4. OVSEE
# 5. OVSAE
# 6. VHAC
# 7. OVPT
# 8. PL.5000
# 9. PO2SM

# %%
gm_dict, c_dict, df_ime = cluster_dictionary(df_ime)

# %%
gm_df, c_df = clustering_dataframes(gm_dict, c_dict)

# %% [markdown]
# ### Results analysis

# %% [markdown]
# #### Dataframe comparison

# %%
print("\nClasificación original de los estados:")
gm_df
# Out:
# Clasificación original de los estados:
#                   0_muy_bajo               1_bajo       2_medio  \
# 2015 0       Baja California       Aguascalientes       Durango
#      1  Coahuila de Zaragoza  Baja California Sur    Guanajuato
#      2      Distrito Federal               Colima       Morelos
#      3            Nuevo León            Chihuahua       Nayarit
#      4                     -              Jalisco  Quintana Roo
#      5                     -               México       Sinaloa
#      6                     -            Querétaro       Tabasco
#      7                     -               Sonora      Tlaxcala
#      8                     -           Tamaulipas     Zacatecas
#
#                                  3_alto 4_muy_alto
# 2015 0                         Campeche    Chiapas
#      1                          Hidalgo   Guerrero
#      2              Michoacán de Ocampo     Oaxaca
#      3                           Puebla          -
#      4                  San Luis Potosí          -
#      5  Veracruz de Ignacio de la Llave          -
#      6                          Yucatán          -
#      7                                -          -
#      8                                -          -

# %%
print("\nClasificación usando features originales (9):")
# print("\nClasificación usando componentes principales (5):")
c_df
# Out:
# Clasificación usando features originales (9):
#                            0_muy_bajo          1_bajo     2_medio  \
# 2015 0                Baja California  Aguascalientes    Campeche
#      1            Baja California Sur          Colima     Durango
#      2           Coahuila de Zaragoza       Chihuahua  Guanajuato
#      3               Distrito Federal         Jalisco     Morelos
#      4                     Nuevo León          México     Nayarit
#      5                              -    Quintana Roo   Querétaro
#      6                              -          Sonora     Sinaloa
#      7                              -      Tamaulipas    Tlaxcala
#      8                              -               -     Yucatán
#      ----------            ----------      ----------  ----------
#      Correct                        4               7           6
#      Incorrect                      1               1           3
#      Missing                        0               2           3
#
#                                           3_alto  4_muy_alto
# 2015 0                                   Hidalgo     Chiapas
#      1                       Michoacán de Ocampo    Guerrero
#      2                                    Puebla      Oaxaca
#      3                           San Luis Potosí           -
#      4                                   Tabasco           -
#      5           Veracruz de Ignacio de la Llave           -
#      6                                 Zacatecas           -
#      7                                         -           -
#      8                                         -           -
#      ----------                       ----------  ----------
#      Correct                                   5           3
#      Incorrect                                 2           0
#      Missing                                   2           0

# %% [markdown]
# #### Confusion matrix

# %%
print("\nMatriz de confusión usando features originales (9):")
# print("\nClasificación usando componentes principales (5):")
display_confusion_matrix(df_ime)
# Out:
# Matriz de confusión usando features originales (9):

# %% [markdown]
# ---

# %% [markdown]
# ## *Notes*

# %% [markdown]
# - Sources
#     - [An Introduction to Clustering Algorithms in Python](https://towardsdatascience.com/an-introduction-to-clustering-algorithms-in-python-123438574097)

# %% [markdown]
# ---

# %% [markdown]
# ### Creating features dicts

# %% [raw]
# feat_dict = {}
# for col in df_pca.columns:
#     feat_dict[col] = {
#         "feature": True,
#         "selected": True
#     }
#
# json_dump_dict(feat_dict)

# %% [markdown]
# ---
# ---
